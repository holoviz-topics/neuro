# %% [markdown]
# # Launch the MNE Qt-based EEG viewer with sample data

# %% [markdown]
# 1. Install the follwing from conda-forge:
# - `mne-base h5io h5py pymatreader jupyterlab pandas mne-qt-browser`

# %% [markdown]
# 2. Download data
# - for example: `https://physionet.org/files/eegmmidb/1.0.0/S001/S001R04.edf?download`

# %% [markdown]
# 3. Read data

# %%
sample_data_raw_file = ('/Users/droumis/data/mne_data/S001R04.edf') # your path to data
sample_data_raw_file
# Out:
# '/Users/droumis/data/mne_data/S001R04.edf'

# %%
# %gui qt5
import mne

# %%
raw = mne.io.read_raw_edf(sample_data_raw_file)
# Out:
# Extracting EDF parameters from /Users/droumis/data/mne_data/S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %% [markdown]
# 4. Launch Qt EEG viewer

# %%
raw.plot(duration=10, n_channels=40, clipping=None)
# Out:
# Using qt as 2D backend.
# Using pyopengl with version 3.1.6
# 2023-08-09 16:22:24.001 python[5491:11275801] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 2462, in _select_annotations
#     self.weakmain()._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 2462, in _select_annotations
#     self.weakmain()._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# /Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py:346: RuntimeWarning: Error sending hover exit event:
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 461, in advance_eventloop
#     eventloop(self)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/widgets/GraphicsView.py", line 343, in mouseReleaseEvent
#     super().mouseReleaseEvent(ev)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 216, in mouseReleaseEvent
#     if self.sendDragEvent(ev, final=True):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 346, in sendDragEvent
#     debug.printExc("Error sending hover exit event:")
#   --- exception caught here ---
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 344, in sendDragEvent
#     self.dragItem.mouseDragEvent(event)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 1293, in mouseDragEvent
#     self.weakmain()._remove_region(
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4128, in _remove_region
#     self.mne.overview_bar.update_annotations()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 923, in update_annotations
#     annot_set = set([annot['onset'] for annot in annotations if
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 924, in <listcomp>
#     self.mne.visible_annotations[annot['description']]])
# KeyError: 'Te'
#   debug.printExc("Error sending hover exit event:")
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
# ...
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 3778, in _xrange_changed
#     self._update_regions_visible()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4229, in _update_regions_visible
#     if self.mne.visible_annotations[region.description]:
# KeyError: 'Test1'
# /Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py:346: RuntimeWarning: Error sending hover exit event:
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 461, in advance_eventloop
#     eventloop(self)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/widgets/GraphicsView.py", line 343, in mouseReleaseEvent
#     super().mouseReleaseEvent(ev)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 216, in mouseReleaseEvent
#     if self.sendDragEvent(ev, final=True):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 346, in sendDragEvent
#     debug.printExc("Error sending hover exit event:")
#   --- exception caught here ---
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 344, in sendDragEvent
#     self.dragItem.mouseDragEvent(event)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 1302, in mouseDragEvent
#     self.mne.overview_bar.update_annotations()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 923, in update_annotations
#     annot_set = set([annot['onset'] for annot in annotations if
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 924, in <listcomp>
#     self.mne.visible_annotations[annot['description']]])
# KeyError: 'Te'
#   debug.printExc("Error sending hover exit event:")
# /Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py:346: RuntimeWarning: Error sending hover exit event:
# Traceback (most recent call last):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 461, in advance_eventloop
#     eventloop(self)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/ipykernel/eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/widgets/GraphicsView.py", line 343, in mouseReleaseEvent
#     super().mouseReleaseEvent(ev)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 216, in mouseReleaseEvent
#     if self.sendDragEvent(ev, final=True):
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 346, in sendDragEvent
#     debug.printExc("Error sending hover exit event:")
#   --- exception caught here ---
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/pyqtgraph/GraphicsScene/GraphicsScene.py", line 344, in sendDragEvent
#     self.dragItem.mouseDragEvent(event)
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 1293, in mouseDragEvent
#     self.weakmain()._remove_region(
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 4128, in _remove_region
#     self.mne.overview_bar.update_annotations()
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 923, in update_annotations
#     annot_set = set([annot['onset'] for annot in annotations if
#   File "/Users/droumis/opt/miniconda3/envs/neuro-eeg-viewer/lib/python3.9/site-packages/mne_qt_browser/_pg_figure.py", line 924, in <listcomp>
#     self.mne.visible_annotations[annot['description']]])
# KeyError: 'Te'
#   debug.printExc("Error sending hover exit event:")
# Channels marked as bad:
# none

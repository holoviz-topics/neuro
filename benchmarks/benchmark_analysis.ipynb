# %% [markdown]
# ## plot hists

# %%
import pandas as pd
import hvplot.pandas
import copy

samples = [
    [0.060286249965429306, 0.046920208958908916, 0.05193449999205768, 0.03579441690817475, 0.04708758310880512, 0.07347645808476955, 0.043446792056784034, 0.025806416990235448, 0.04181495797820389, 0.05058133299462497],
    [0.059569125063717365, 0.03739483398385346, 0.047367374994792044, 0.031105250003747642, 0.07649579201824963, 0.06200483301654458, 0.042369082919321954, 0.038068082998506725, 0.04816204193048179, 0.040613707969896495],
    [0.06403725000564009, 0.03954258293379098, 0.035274417023174465, 0.04176937497686595, 0.03126758395228535, 0.04993283306248486, 0.03175550000742078, 0.030677375034429133, 0.04232825001236051, 0.041517874924466014],
    [0.053124082973226905, 0.047464750008657575, 0.0389691669261083, 0.04687395808286965, 0.04964637500233948, 0.057078792015090585, 0.0383075000718236, 0.05167933402117342, 0.0286780419992283, 0.0356168340658769],
    [0.09045729099307209, 0.06331237498670816, 0.0779080829815939, 0.07486062496900558, 0.07882891595363617, 0.07927791704423726, 0.07322799996472895, 0.07348079094663262, 0.07656741701066494, 0.07188441604375839],
    [0.08690187497995794, 0.0726179169723764, 0.05977462499868125, 0.057303749956190586, 0.06297133304178715, 0.08912837505340576, 0.05677529098466039, 0.07166549994144589, 0.06013716710731387, 0.04923649993725121],
    [0.324318208033219, 0.2796119999838993, 0.28359495801851153, 0.28139824990648776, 0.2915940419770777, 0.32305400003679097, 0.2930110839661211, 0.2884300419827923, 0.2824998339638114, 0.2886389170307666],
    [0.2589865840272978, 0.2383861249545589, 0.2334213750436902, 0.2347428749781102, 0.2375649999594316, 0.24843024997971952, 0.2323590830201283, 0.24640008294954896, 0.2365097909932956]
]

n_values = [1000, 10000, 100000, 1000000]
output_backends = ["canvas", "webgl"]

samples_copy = copy.deepcopy(samples)

# there's a missing value in the last list.. add a placeholder.
samples_copy[-1].append(float('nan'))


n_list = []
backend_list = []
time_list = []

for idx, sample in enumerate(samples_copy):
    n = n_values[idx // 2]
    backend = output_backends[idx % 2]
    for time in sample:
        n_list.append(n)
        backend_list.append(backend)
        time_list.append(time)

df_corrected = pd.DataFrame({
    'n': n_list,
    'backend': backend_list,
    'time': time_list
})

plot = df_corrected.hvplot.hist(y='time', by=['n', 'backend'], bins=30, width=300, height=200, subplots=True).cols(2)
plot
# Out:
# :NdLayout   [n,backend]
#    :Histogram   [time]   (time_count)

# %% [markdown]
# ## plot curves

# %%
import pandas as pd
import copy
import hvplot.pandas
import holoviews as hv; hv.extension('bokeh')
import panel as pn; pn.extension()

samples = [
    [0.060286249965429306, 0.046920208958908916, 0.05193449999205768, 0.03579441690817475, 0.04708758310880512, 0.07347645808476955, 0.043446792056784034, 0.025806416990235448, 0.04181495797820389, 0.05058133299462497],
    [0.059569125063717365, 0.03739483398385346, 0.047367374994792044, 0.031105250003747642, 0.07649579201824963, 0.06200483301654458, 0.042369082919321954, 0.038068082998506725, 0.04816204193048179, 0.040613707969896495],
    [0.06403725000564009, 0.03954258293379098, 0.035274417023174465, 0.04176937497686595, 0.03126758395228535, 0.04993283306248486, 0.03175550000742078, 0.030677375034429133, 0.04232825001236051, 0.041517874924466014],
    [0.053124082973226905, 0.047464750008657575, 0.0389691669261083, 0.04687395808286965, 0.04964637500233948, 0.057078792015090585, 0.0383075000718236, 0.05167933402117342, 0.0286780419992283, 0.0356168340658769],
    [0.09045729099307209, 0.06331237498670816, 0.0779080829815939, 0.07486062496900558, 0.07882891595363617, 0.07927791704423726, 0.07322799996472895, 0.07348079094663262, 0.07656741701066494, 0.07188441604375839],
    [0.08690187497995794, 0.0726179169723764, 0.05977462499868125, 0.057303749956190586, 0.06297133304178715, 0.08912837505340576, 0.05677529098466039, 0.07166549994144589, 0.06013716710731387, 0.04923649993725121],
    [0.324318208033219, 0.2796119999838993, 0.28359495801851153, 0.28139824990648776, 0.2915940419770777, 0.32305400003679097, 0.2930110839661211, 0.2884300419827923, 0.2824998339638114, 0.2886389170307666],
    [0.2589865840272978, 0.2383861249545589, 0.2334213750436902, 0.2347428749781102, 0.2375649999594316, 0.24843024997971952, 0.2323590830201283, 0.24640008294954896, 0.2365097909932956]
]

n_values = [1000, 10000, 100000, 1000000]
output_backends = ["canvas", "webgl"]

samples_copy = copy.deepcopy(samples)
samples_copy[-1].append(float('nan'))

n_list = []
backend_list = []
time_list = []

for idx, sample in enumerate(samples_copy):
    n = n_values[idx // 2]
    backend = output_backends[idx % 2]
    for time in sample:
        n_list.append(n)
        backend_list.append(backend)
        time_list.append(time)

df_corrected = pd.DataFrame({
    'n': n_list,
    'backend': backend_list,
    'time': time_list
})

df_summary = df_corrected.groupby(['n', 'backend']).agg(
    mean_time=('time', 'mean'),
    std_time=('time', 'std')
).reset_index()

color_mapping = {'canvas': 'blue', 'webgl': 'orange'}
df_corrected['color'] = df_corrected['backend'].map(color_mapping)
df_summary['color'] = df_summary['backend'].map(color_mapping)

lines = df_summary.hvplot.line(x='n', y='mean_time', by='backend', color='color', label=backend)
points = df_corrected.hvplot.scatter(x='n', y='time', by='backend', color='color', alpha=0.5)

overlay = lines * points
overlay = overlay.opts(xticks=n_values, xlabel='Num Samples', xrotation=90, ylabel='Time (s)', width=500, height=400, title="Mean Time by Backend", legend_position='top_left')
overlay = overlay.redim.range(n=(df_summary.n.min()-df_summary.n.min()*100, df_summary.n.max()*1.1))
pn.Row(df_summary.drop(['color'], axis=1), overlay)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
# ...
